# %%
import pandas as pd

# %%
df = list(pd.read_csv("C:/Users/jutnl/recursiveparadox/StockProphet/SPY_components", index_col=0)["Symbol"])

# %%
df = pd.read_csv("SPY_components", index_col=0)["Symbol"]

# %%
df
# Out:
# ['MSFT',
#  'AAPL',
#  'AMZN',
#  'FB',
#  'BRK.B',
#  'GOOG',
#  'JNJ',
#  'GOOGL',
#  'XOM',
#  'JPM',
#  'V',
#  'PG',
#  'VZ',
#  'BAC',
#  'INTC',
#  'UNH',
#  'CVX',
#  'PFE',
#  'CSCO',
#  'T',
#  'HD',
#  'MRK',
#  'MA',
#  'WFC',
#  'DIS',
#  'BA',
#  'CMCSA',
#  'KO',
#  'PEP',
#  'NFLX',
#  'C',
#  'MCD',
#  'PM',
#  'WMT',
#  'ABT',
#  'ORCL',
#  'ADBE',
#  'IBM',
#  'CRM',
#  'DWDP',
#  'MDT',
#  'PYPL',
#  'MMM',
#  'ABBV',
#  'AMGN',
#  'UNP',
#  'AVGO',
#  'HON',
#  'LLY',
#  'NVDA',
#  'TMO',
#  'ACN',
#  'MO',
#  'COST',
#  'NKE',
#  'TXN',
#  'UTX',
#  'LIN',
#  'NEE',
#  'SBUX',
#  'GE',
#  'AMT',
#  'LOW',
#  'GILD',
#  'DHR',
#  'BMY',
#  'ANTM',
#  'BKNG',
#  'AXP',
#  'COP',
#  'UPS',
#  'CAT',
#  'CVS',
#  'USB',
#  'LMT',
#  'MDLZ',
#  'QCOM',
#  'ADP',
#  'DUK',
#  'INTU',
#  'GS',
#  'TJX',
#  'BDX',
#  'ISRG',
#  'CI',
#  'CB',
#  'CHTR',
#  'CELG',
#  'D',
#  'SYK',
#  'SLB',
#  'CME',
#  'CL',
#  'CSX',
#  'SPG',
#  'EOG',
#  'MS',
#  'PNC',
#  'SO',
# ...
