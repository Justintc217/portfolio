# %%
import pygame
import sys
import time
import random

from pygame.locals import *

FPS = 16
pygame.init()
fpsClock=pygame.time.Clock()

SCREEN_WIDTH, SCREEN_HEIGHT = 1600, 800
screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT), 0, 32)
surface = pygame.Surface(screen.get_size())
surface = surface.convert()
mur = pygame.Surface((100,200))
surface.fill((255,255,255))
clock = pygame.time.Clock()

pygame.key.set_repeat(1, 40)

GRIDSIZE=300
GRID_WIDTH = SCREEN_WIDTH / GRIDSIZE
GRID_HEIGHT = SCREEN_HEIGHT / GRIDSIZE
UP    = (0, -1)
DOWN  = (0, 1)
LEFT  = (-1, 0)
RIGHT = (1, 0)
    
screen.blit(surface, (0,0))

def draw_box(surf, color, pos):
    r = pygame.Rect((pos[0], pos[1]), (GRIDSIZE, GRIDSIZE))
    pygame.draw.rect(surf, color, r)

class Snake(object):
    def __init__(self):
        self.lose()
        self.color = (0,0,0)

    def get_head_position(self):
        return self.positions[0]

    def lose(self):
        self.length = 1
        self.positions =  [((SCREEN_WIDTH / 2), (SCREEN_HEIGHT / 2))]
        self.direction = random.choice([UP, DOWN, LEFT, RIGHT])

    def point(self, pt):
        if self.length > 1 and (pt[0] * -1, pt[1] * -1) == self.direction:
            return
        else:
            self.direction = pt

    def move(self):
        cur = self.positions[0]
        x, y = self.direction
        new = (((cur[0]+(x*GRIDSIZE)) % SCREEN_WIDTH), (cur[1]+(y*GRIDSIZE)) % SCREEN_HEIGHT)
        if len(self.positions) > 2 and new in self.positions[2:]:
            self.lose()
        else:
            self.positions.insert(0, new)
            if len(self.positions) > self.length:
                self.positions.pop()
    
    def draw(self, surf):
        for p in self.positions:
            draw_box(surf, self.color, p)

class Apple(object):
    def __init__(self):
        self.position = (0,0)
        self.color = (255,0,0)
        self.randomize()

    def randomize(self):
        self.position = (random.randint(0, GRID_WIDTH-1) * GRIDSIZE, random.randint(0, GRID_HEIGHT-1) * GRIDSIZE)

    def draw(self, surf):
        draw_box(surf, self.color, self.position)

def check_eat(snake, apple):
    if snake.get_head_position() == apple.position:
        snake.length += 100
        apple.randomize()

if __name__ == '__main__':
    snake = Snake()
    juan = Snake()
    apple = Apple()
    while True:

        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()
            elif event.type == KEYDOWN:
                if event.key == K_UP:
                    snake.point(UP)
                elif event.key == K_DOWN:
                    snake.point(DOWN)
                elif event.key == K_LEFT:
                    snake.point(LEFT)
                elif event.key == K_RIGHT:
                    snake.point(RIGHT)
                elif event.key == K_w:
                    juan.point(UP)
                elif event.key == K_s:
                    juan.point(DOWN)
                elif event.key == K_a:
                    juan.point(LEFT)
                elif event.key == K_d:
                    juan.point(RIGHT)


        surface.fill((255,255,255))
        snake.move()
        juan.move()
        check_eat(snake, apple)
        snake.draw(surface)
        #juan.draw(mur)
        apple.draw(surface)
        font = pygame.font.Font(None, 36)
        text = font.render(str(snake.length), 1, (10, 10, 10))
        textpos = text.get_rect()
        surface.blit(text, textpos)
        screen.blit(surface, (0,0))

        pygame.display.flip()
        pygame.display.update()
        fpsClock.tick(FPS)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-d6786e09c6e4> in <module>()
#      88     snake = Snake()
#      89     juan = Snake()
# ---> 90     apple = Apple()
#      91     while True:
#      92
#
# <ipython-input-10-d6786e09c6e4> in __init__(self)
#      72         self.position = (0,0)
#      73         self.color = (255,0,0)
# ---> 74         self.randomize()
#      75
#      76     def randomize(self):
#
# <ipython-input-10-d6786e09c6e4> in randomize(self)
#      75
#      76     def randomize(self):
# ---> 77         self.position = (random.randint(0, GRID_WIDTH-1) * GRIDSIZE, random.randint(0, GRID_HEIGHT-1) * GRIDSIZE)
#      78
#      79     def draw(self, surf):
#
# ~\Anaconda3\lib\random.py in randint(self, a, b)
#     219         """
#     220
# --> 221         return self.randrange(a, b+1)
#     222
#     223     def _randbelow(self, n, int=int, maxsize=1<<BPF, type=type,
#
# ~\Anaconda3\lib\random.py in randrange(self, start, stop, step, _int)
#     192         istop = _int(stop)
#     193         if istop != stop:
# --> 194             raise ValueError("non-integer stop for randrange()")
#     195         width = istop - istart
#     196         if step == 1 and width > 0:
#
# ValueError: non-integer stop for randrange()

# %%
pygame.Surface?

# %%
snake.draw?

# %%
elif event.type == KEYDOWN:
    if event.key == K_w:
        juan.point(UP)
    elif event.key == K_s:
        juan.point(DOWN)
    elif event.key == K_a:
        juan.point(LEFT)
    elif event.key == K_d:
        juan.point(RIGHT)
